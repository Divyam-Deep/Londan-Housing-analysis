# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyam-Deep/Londan-Housing-analysis/blob/main/Londan_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = pd.read_csv('/content/Housing+Data.csv')
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.shape
# Out:
# (13549, 6)

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.no_of_crimes.fillna('Not Mentioned', inplace = True)
# Out:
# <ipython-input-62-5232ee42da36>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.no_of_crimes.fillna('Not Mentioned', inplace = True)
# <ipython-input-62-5232ee42da36>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Mentioned' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.no_of_crimes.fillna('Not Mentioned', inplace = True)

# %%
data.isnull().sum()
# Out:
# date              0
# area              0
# average_price     0
# code              0
# houses_sold      94
# no_of_crimes      0
# dtype: int64

# %%
data.houses_sold.fillna(data.houses_sold.mean(), inplace = True)
# Out:
# <ipython-input-64-6e863a9eefb0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.houses_sold.fillna(data.houses_sold.mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# date             0
# area             0
# average_price    0
# code             0
# houses_sold      0
# no_of_crimes     0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes      object
# dtype: object

# %%
data.date = pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes             object
# dtype: object

# %%
data.head(10)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
# 5 1995-06-01  city of london          94901  E09000001         17.0
# 6 1995-07-01  city of london         110128  E09000001         13.0
# 7 1995-08-01  city of london         112329  E09000001         14.0
# 8 1995-09-01  city of london         104473  E09000001         17.0
# 9 1995-10-01  city of london         108038  E09000001         14.0
#
#     no_of_crimes
# 0  Not Mentioned
# 1  Not Mentioned
# 2  Not Mentioned
# 3  Not Mentioned
# 4  Not Mentioned
# 5  Not Mentioned
# 6  Not Mentioned
# 7  Not Mentioned
# 8  Not Mentioned
# 9  Not Mentioned

# %%
data['Years'] = data.date.dt.year

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#     no_of_crimes  Years
# 0  Not Mentioned   1995
# 1  Not Mentioned   1995
# 2  Not Mentioned   1995
# 3  Not Mentioned   1995
# 4  Not Mentioned   1995

# %%
data['Months'] = data.date.dt.month

# %%
data.insert(1,'Months',data.pop('Months'))

# %%
data.head()
# Out:
#         date  Months            area  average_price       code  houses_sold  \
# 0 1995-01-01       1  city of london          91449  E09000001         17.0
# 1 1995-02-01       2  city of london          82203  E09000001          7.0
# 2 1995-03-01       3  city of london          79121  E09000001         14.0
# 3 1995-04-01       4  city of london          77101  E09000001          7.0
# 4 1995-05-01       5  city of london          84409  E09000001         10.0
#
#     no_of_crimes  Years
# 0  Not Mentioned   1995
# 1  Not Mentioned   1995
# 2  Not Mentioned   1995
# 3  Not Mentioned   1995
# 4  Not Mentioned   1995

# %%
data.drop(['Months'], axis = 1, inplace =True)

# %%
data[data.no_of_crimes == 0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#     no_of_crimes  Years
# 72           0.0   2001
# 73           0.0   2001
# 74           0.0   2001
# 75           0.0   2001
# ...

# %%
len(data[data.no_of_crimes == 0])
# Out:
# 104

# %%
data[data.area == 'england'].groupby('Years').average_price.describe()
# Out:
#        count           mean          std       min        25%       50%  \
# Years
# 1995    12.0   53322.416667   373.548210   52788.0   53052.50   53256.0
# 1996    12.0   54151.500000  1199.646804   52333.0   53169.00   54398.5
# 1997    12.0   59160.666667  2137.956728   55789.0   57378.75   59614.5
# 1998    12.0   64301.666667  1558.265897   61659.0   63312.75   65001.0
# 1999    12.0   70070.750000  3370.946404   65522.0   67330.50   70020.0
# 2000    12.0   80814.333333  3265.159674   75219.0   78980.25   81916.0
# 2001    12.0   90306.750000  4266.146998   84245.0   86889.75   90705.0
# 2002    12.0  107981.500000  8470.434587   96215.0  100756.75  108406.0
# 2003    12.0  130218.583333  6052.596324  121610.0  125493.75  130835.5
# 2004    12.0  152314.416667  8036.872000  139719.0  146080.25  155128.5
# 2005    12.0  163570.000000  3240.674116  158572.0  160912.50  164853.0
# 2006    12.0  174351.500000  5291.164788  166544.0  170347.00  175197.5
# ...

# %%
data.groupby('area').no_of_crimes.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
data.no_of_crimes.replace({'Not Mentioned': 0}, inplace =True)
# Out:
# <ipython-input-102-a996e4660ef6>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.no_of_crimes.replace({'Not Mentioned': 0}, inplace =True)

# %%
data.groupby('area').no_of_crimes.max().sort_values(ascending = False)
# Out:
# area
# westminster               7461.0
# lambeth                   4701.0
# camden                    4558.0
# southwark                 3821.0
# newham                    3668.0
# hackney                   3466.0
# ealing                    3401.0
# islington                 3384.0
# tower hamlets             3316.0
# croydon                   3263.0
# haringey                  3199.0
# wandsworth                3051.0
# waltham forest            2941.0
# brent                     2937.0
# barnet                    2893.0
# greenwich                 2853.0
# hillingdon                2819.0
# hounslow                  2817.0
# lewisham                  2813.0
# enfield                   2798.0
# kensington and chelsea    2778.0
# hammersmith and fulham    2645.0
# bromley                   2637.0
# redbridge                 2560.0
# barking and dagenham      2049.0
# havering                  1956.0
# bexley                    1914.0
# harrow                    1763.0
# ...

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Years
# 0           0.0   1995
# 1           0.0   1995
# 2           0.0   1995
# 3           0.0   1995
# 4           0.0   1995

# %%
data[data['average_price']< 100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
